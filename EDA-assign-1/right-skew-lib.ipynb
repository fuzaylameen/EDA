# %%
import numpy as np
from scipy import stats

# Dataset
data = [10, 12, 13, 14, 15, 18, 40]

# Mean
mean = np.mean(data)

# Median
median = np.median(data)

# Mode
mode_result = stats.mode(data, keepdims=False)
mode = mode_result.mode if mode_result.count > 1 else None

# Variance (sample variance)
variance = np.var(data, ddof=1)

# Standard Deviation
std_dev = np.std(data, ddof=1)

# Skewness
skewness = stats.skew(data)

# Print results
print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
print("Skewness:", skewness)
# Out:
# Mean: 17.428571428571427
# Median: 14.0
# Mode: None
# Variance: 105.28571428571428
# Standard Deviation: 10.260882724488877
# Skewness: 1.7977064193761716
